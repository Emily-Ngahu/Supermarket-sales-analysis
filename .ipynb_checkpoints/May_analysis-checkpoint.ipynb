# %% [markdown]
# # Supermarket sales analysis

# %% [markdown]
# This project aims to leverage sales data from my local supermarket to identify best-selling items and categories
# This will help in inventory management and to know how to adjust prices so as to get more sales
#
# ## Objectives
# 1. Identify best-selling items and categories.
# 2. Determine sales patterns and seasonality
# 3. Track inventory levels and forecast demand
# 4. Analyze the impact of tax on overall sales

# %% [markdown]
# ## Data
# The data used was collected from a local supermarket in Murang'a, Kenya. The data is in two parts: May and june 2024 sales data, that will be worked on differently.
#
# The data contains the following columns:
# 1. Item id - This is the unique item identifer.
# 2. Description - This describes the item in terms of quantity eg KENSALT 500GMS, SOKO ALL PURPOSE 2KG BALE.
# 3. Qty Sold - Gives in numbers the amount /quantity of the item sold.
# 4. Sold Price - the price the item was sold at.
# 5. Total sales - gives the tota sales for the given item which is basically (Qty Sold * Sold Price)
# 6. Total(Tax EX) - This is the tax-excluded amount. This represents the revenue generated from sales before any sales tax is applied.
# 7. Sales tax - This represents the amount of tax collected on the sale of each item.

# %%
#importing libraries 
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
#importing data
May_sales = pd.read_csv("C:/Users/ADMIN/Documents/Supermarket-sales-analysis/May_supermarket_sales.csv")

# %%
May_sales.head()
# Out:
#        Item                    Description  Qty_Sold  Sold_Price  Total_Sales  \
# 0       D30                 DOUBLE BISCUIT       3.0          30           90
# 1  6.16E+12  DAWN PEKEE TISSUE SINGLE PACK       1.0          30           30
# 2  6.17E+12   GRACIES STRAWBERRY CUP 250ML       1.0          60           60
# 3       D30                 DOUBLE BISCUIT       2.0          30           60
# 4  6.17E+12  ELLY'S &JAYS PURE SEASALT 1KG       1.0         290          290
#
#    Total (Tax_Ex)  Sales_Tax
# 0         77.5862    12.4138
# 1         30.0000     0.0000
# 2         51.7241     8.2759
# 3         51.7241     8.2759
# 4        290.0000     0.0000

# %%
May_sales.tail()
# Out:
#             Item                     Description  Qty_Sold  Sold_Price  \
# 107099       301             CENTRAL BIRYANI 1Kg       2.0         120
# 107100  6.16E+12  ELLYS & JAYS ROASTED CLAY 100G       1.0          40
# 107101       301             CENTRAL BIRYANI 1Kg       1.0         120
# 107102     18599              BIRTHDAY CAKE 500G       1.0         600
# 107103       C20                        COCKTAIL       5.0          20
#
#         Total_Sales  Total (Tax_Ex)  Sales_Tax
# 107099          240        240.0000     0.0000
# 107100           40         34.4828     5.5172
# 107101          120        120.0000     0.0000
# 107102          600        517.2414    82.7586
# 107103          100         86.2069    13.7931

# %% [markdown]
# ## Data cleaning and validation

# %% [markdown]
# Cleaning the data will consist of checking for null, empty, missing and duplicated values.

# %%
# Check for null values in the dataset
null_values = May_sales.isnull().sum()

print(f'Null values in each column:\n{null_values}')
# Out:
# Null values in each column:
# Item              18
# Description       19
# Qty_Sold           0
# Sold_Price         0
# Total_Sales        0
# Total (Tax_Ex)     0
# Sales_Tax          0
# dtype: int64

# %%
# rows with null values
May_sales[May_sales['Item'].isnull()]
# Out:
#        Item Description  Qty_Sold  Sold_Price  Total_Sales  Total (Tax_Ex)  \
# 44124   NaN         NaN       1.0         150          150        129.3104
# 80684   NaN         NaN       1.0           0            0          0.0000
# 80685   NaN         NaN       1.0           0            0          0.0000
# 90650   NaN         NaN       2.0         150          300        258.6207
# 98028   NaN         NaN       1.0          55           55         55.0000
# 98686   NaN         NaN       1.0          55           55         55.0000
# 99910   NaN         NaN       1.0         150          150        129.3104
# 100878  NaN         NaN       1.0          55           55         55.0000
# 102814  NaN         NaN       1.0          55           55         55.0000
# 103713  NaN         NaN       1.0          55           55         55.0000
# 103943  NaN         NaN       1.0          55           55         55.0000
# 104330  NaN         NaN       1.0          55           55         55.0000
# 105834  NaN         NaN       1.0          55           55         55.0000
# 105871  NaN         NaN       1.0          55           55         55.0000
# 106309  NaN         NaN       1.0          55           55         55.0000
# 106693  NaN         NaN       1.0          55           55         55.0000
# 106765  NaN         NaN       2.0          55          110        110.0000
# 107039  NaN         NaN       0.0           0            0          0.0000
#
#         Sales_Tax
# 44124     20.6896
# 80684      0.0000
# 80685      0.0000
# 90650     41.3793
# 98028      0.0000
# 98686      0.0000
# 99910     20.6896
# 100878     0.0000
# 102814     0.0000
# 103713     0.0000
# 103943     0.0000
# 104330     0.0000
# 105834     0.0000
# 105871     0.0000
# 106309     0.0000
# 106693     0.0000
# 106765     0.0000
# 107039     0.0000

# %%
#rows with null values
May_sales[May_sales['Description'].isnull()]
# Out:
#        Item Description  Qty_Sold  Sold_Price  Total_Sales  Total (Tax_Ex)  \
# 44124   NaN         NaN       1.0         150          150        129.3104
# 80684   NaN         NaN       1.0           0            0          0.0000
# 80685   NaN         NaN       1.0           0            0          0.0000
# 86615   --+         NaN       1.0           0            0          0.0000
# 90650   NaN         NaN       2.0         150          300        258.6207
# 98028   NaN         NaN       1.0          55           55         55.0000
# 98686   NaN         NaN       1.0          55           55         55.0000
# 99910   NaN         NaN       1.0         150          150        129.3104
# 100878  NaN         NaN       1.0          55           55         55.0000
# 102814  NaN         NaN       1.0          55           55         55.0000
# 103713  NaN         NaN       1.0          55           55         55.0000
# 103943  NaN         NaN       1.0          55           55         55.0000
# 104330  NaN         NaN       1.0          55           55         55.0000
# 105834  NaN         NaN       1.0          55           55         55.0000
# 105871  NaN         NaN       1.0          55           55         55.0000
# 106309  NaN         NaN       1.0          55           55         55.0000
# 106693  NaN         NaN       1.0          55           55         55.0000
# 106765  NaN         NaN       2.0          55          110        110.0000
# 107039  NaN         NaN       0.0           0            0          0.0000
#
#         Sales_Tax
# 44124     20.6896
# 80684      0.0000
# 80685      0.0000
# 86615      0.0000
# 90650     41.3793
# 98028      0.0000
# 98686      0.0000
# 99910     20.6896
# 100878     0.0000
# 102814     0.0000
# 103713     0.0000
# 103943     0.0000
# 104330     0.0000
# 105834     0.0000
# 105871     0.0000
# 106309     0.0000
# 106693     0.0000
# 106765     0.0000
# 107039     0.0000

# %% [markdown]
# # Nan values
# NaN (Not a Number) values can arise in a dataset due to various reasons,eg :
# 1. Sensor Failures: In data collected from sensors, there might be periods when the sensor fails to record data.
# 2. System Errors: Automated data entry systems might encounter issues leading to missing values.
#
# Nan values should be removed from the dataset as they :
# 1. can distort statistical analysis and machine learning model training because they represent unknown or missing data. Removing them ensures that the remaining data is accurate and complete.
# 2.  can skew statistical measures such as mean, standard deviation, and correlations. Removing them ensures that statistical analyses are based on valid and complete data
# 3.  can disrupt data visualization processes, making it harder to interpret and present insights effectively. Removing them can lead to clearer and more accurate visual representations.
#
# As seen above, there are 18 null values in the item column and 19 null values in the description column.Since we have large amount of data we can delete the null values.

# %%
#dropping rows with null values
May_sales = May_sales.dropna()

# %%
null_values = May_sales.isnull().sum()

print(f'Null values in each column:\n{null_values}')
# Out:
# Null values in each column:
# Item              0
# Description       0
# Qty_Sold          0
# Sold_Price        0
# Total_Sales       0
# Total (Tax_Ex)    0
# Sales_Tax         0
# dtype: int64

# %%
#checking for duplicates 
May_sales.duplicated().sum()
# Out:
# 98919

# %% [markdown]
# As above, there are 98918 duplicates. This is no cause for alarm as different customers can buy the same items hence there will be alot of duplicates. Because of this we will not delete any duplicates.

# %%
May_sales[May_sales['Qty_Sold']== 0]
# Out:
#             Item                    Description  Qty_Sold  Sold_Price  \
# 101     6.16E+12               NATION NEWSPAPER       0.0          60
# 795     6.16E+12                     POSTMAN 3L       0.0         790
# 1315         L20                 LINZER COOKIES       0.0          20
# 1361       18534             CENTRAL SCONES 9PK       0.0          75
# 1388          30  CAPERINS CHOC CUPS 300G (6PK)       0.0          80
# ...          ...                            ...       ...         ...
# 106545  6.16E+12                   MENENGAI 1KG       0.0         190
# 106702  7.64E+11                 RAHA NGANO 2KG       0.0         175
# 106734  6.16E+12                   MENENGAI 1KG       0.0         190
# 106738         d               TEEPEE G16 BRUSH       0.0          35
# 107011     17089      PACKING BAG #25 NON WOVEN       0.0          20
#
#         Total_Sales  Total (Tax_Ex)  Sales_Tax
# 101               0             0.0        0.0
# 795               0             0.0        0.0
# 1315              0             0.0        0.0
# 1361              0             0.0        0.0
# 1388              0             0.0        0.0
# ...             ...             ...        ...
# 106545            0             0.0        0.0
# 106702            0             0.0        0.0
# 106734            0             0.0        0.0
# 106738            0             0.0        0.0
# 107011            0             0.0        0.0
#
# [650 rows x 7 columns]

# %% [markdown]
# As from above 650 of the items were never sold ,we will take note of them but they are not useful in the analysis hence we will drop them.

# %%
May_sales.shape
# Out:
# (107085, 7)

# %%
#deleting rows where quanity sold is zero 
May_sales = May_sales[May_sales['Qty_Sold'] != 0]

# %%
May_sales.shape
# Out:
# (106435, 7)

# %%
#checking for missing values
May_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 106435 entries, 0 to 107103
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Item            106435 non-null  object
#  1   Description     106435 non-null  object
#  2   Qty_Sold        106435 non-null  float64
#  3   Sold_Price      106435 non-null  int64
#  4   Total_Sales     106435 non-null  int64
#  5   Total (Tax_Ex)  106435 non-null  float64
#  6   Sales_Tax       106435 non-null  float64
# dtypes: float64(3), int64(2), object(2)
# memory usage: 6.5+ MB

# %% [markdown]
# Looks like we have no missing values hence we are good to go.

# %% [markdown]
# # Exploratory data analysis (EDA)
# EDA helps us to understand our data without making any assumptions.

# %%
May_sales.shape
# Out:
# (106435, 7)

# %% [markdown]
# The shape command shows us that we have 107085 rows of data and 7 features.

# %%
May_sales.describe()
# Out:
#             Qty_Sold     Sold_Price    Total_Sales  Total (Tax_Ex)  \
# count  106435.000000  106435.000000  106435.000000   106435.000000
# mean        1.744157     136.402255     164.813915      149.322355
# std        27.733700     288.381848     312.377147      278.676385
# min         0.500000       1.000000       1.000000        0.862100
# 25%         1.000000      50.000000      55.000000       47.413800
# 50%         1.000000      95.000000     110.000000       95.000000
# 75%         1.000000     150.000000     180.000000      163.793100
# max      5000.000000   23500.000000   23500.000000    20258.620700
#
#            Sales_Tax
# count  106435.000000
# mean       15.491559
# std        39.949585
# min         0.000000
# 25%         0.000000
# 50%         8.275900
# 75%        19.310400
# max      3241.379300

# %% [markdown]
# The describe() command will provide the mean, standard deviation and a five number summary of each numerical feature.
# From the summary statistics we can draw that:
# 1. The minimum of quantity sold was 0.5(half a kg) and the maximum was 5000 items
# 2. The minimum price was ksh1. and the maximum was 23500

# %%
sns.countplot(x = 'Description', data = May_sales, palette="hls")
plt.title("Distribution of items");

# %% [markdown]
# The plot above is supposed to show the count of each item but there are too many items hence making it difficult to interprete and even read the plot we will therefore have to group the items to make it easier to plot.

# %%
#checking unique items
len(May_sales['Description'].unique())
# Out:
# 4458

# %% [markdown]
# There are 4458 unique items in the dataset.

# %% [markdown]
# ## List of all items

# %%
# Get all unique items
unique_items = May_sales['Description'].unique()

# Print all unique items
print(unique_items)

# Optionally, convert to a list if needed
unique_items_list = unique_items.tolist()
print(unique_items_list)
# Out:
# ['DOUBLE BISCUIT' 'DAWN PEKEE TISSUE SINGLE PACK'
#  'GRACIES STRAWBERRY CUP 250ML' ... "HAPPY'S TOMATO CRISPS 100G"
#  'KIDS BELT' 'VENUS NOURISHING LOTION 200ML']
# ['DOUBLE BISCUIT', 'DAWN PEKEE TISSUE SINGLE PACK', 'GRACIES STRAWBERRY CUP 250ML', "ELLY'S &JAYS PURE SEASALT 1KG", 'candle 1 pc', 'DAIRY MILK TOP DECK 80GM', "TROPICAL SWEET 3'S", 'CENTRAL BIRYANI 1Kg', 'PACKING BAG #22 NON WOVEN', 'NESTLE MILO 90G', 'NESCAFE CLASSIC 15G', 'BLUE BAND ORIGINAL 250g', 'BROADWAYS WHITE BREAD 400G', 'ROYAL YOGHURT VANILLA CUP500ML', 'GRACIES PASSION 500ML CUP', 'MANJI CAKE SNACK ORANGE &CHOCO', 'JOY MINI MADEIRA CAKE 350GMS', 'GEISHA BLACK SOAP 200G', 'swiss 30g', 'TOOTH PICK', 'KLEESOFT ANTIBACTERIAL 500GMS', 'JOY MUFFIN CAKE 6PCS 300GMS', 'DORMANS 3-IN-1 CLASSIC 18G', 'CLASSIC HERBAL SOAP 1KG', 'DOWNY SUNRISE', 'CLASSIC  POWDER 1KG', 'AJAB WHEAT FLOUR 2kg', 'SEB BUN', 'DAWN PEKEE SMART', 'SUMO CANDLES 8PCS', 'TAMAM MAIZE MEAL 2KG', 'MWANZO MPYA 1KG', 'CENTRAL SUGAR 1/2', 'RAHA COCOA 20G', 'NESCAFE CLASSIC 1.5GMS', 'KIWI BLACK 100ML', 'KANGAROO SHOE CREAM 65ML', 'CENTRAL  BREAD 600G', 'SATIS QUEEN CAKES 12pcs 400G', 'CENTRAL SUGAR 1KG', 'TROPICAL HEAT POTATO CRISPS SA', 'GRACIES STRAWBERRY CUP 500ML', 'D/LAND REAL WHITE CHOCOLATE 20', 'SKY BRITE SPONGE SCOURER 2PACK', 'KOTEX  LINERS NORMAL 20s', 'JOY SUPER BAKERS MANDAZI 180GM', 'CENTRAL  W/ MEAL BREAD  500GM', 'JOY CHOCO MUFFINS 6PCS', 'SIFA 2 PACK', 'ENERGY GLUCOSE BISCUIT', 'PRESTIGE MARGARINE VANILLA 250', 'MOUNTAIN FRESH LONG LIFE 500ML', 'GRACIE STRAWBERRY CUP 150ML', 'BIG BOM SWEET', 'JAMAA LUXURY BATH SOAP 125G', 'PACKING BAG #25 NON WOVEN', "SWEET 3'S", 'CENTRAL SWEET BREAD 400GM', 'BELLA TOILET JUMBO ROLL', 'DAWN PEKEE POA SINGLE', 'SOKO ALL PURPOSE 1KG', 'BLUEBAND CHOCO 250GMS', 'STELLY SIGLE', 'NDUME 1KG', 'FARMERS BEEF SMOKIES 400G', 'REXONA COTTON', 'KLEENIT SUFURIA SCRUBER MEGA', 'KLEENIT POT SCRUBBER 1PC', 'YEGO ENERGY MILK&GLUCOSE 60GMS', 'A5 NOTE BOOK 200PAGES', 'MUFFIN', 'Chocolate cake slice', '"SIFA SERVIETTES 100""S"', 'nan 3', 'MARBLE/ BLOCK CAKE', 'CENTRAL QUEEN CAKE', 'CENTRAL SCONES 9PK', 'RASANA DARK SOY SAUCE 623ML', 'TROPICAL HEAT PILAU MASALA 100', 'NATION NEWSPAPER', 'OMO REGULAR BLEACH 70ML', 'RINA VEGETABLE OIL 2L', 'MAISHA FLOUR 1KG', 'KENSALT 500GMS', 'NICE N LOVELY CARROT OIL 180ML', 'BLUE BAND ORGINAL 100G', 'NEPTUNE GREEN TISSUE', 'SUPERFINE T/BRUSH 2PC', 'PEPSODENT 30G', 'STAINLESS GLASS', 'YAMI CLASSIC 400G', 'DADDYS CHOICE 1KG', 'savelite   led 9wts', 'enlite 3watts', 'SOKO NGANO WHITE 500G', 'EGG 1 PIECE', 'FANTA ORANGE 1.25LTR', 'RANJU RING CAKE 500G', 'OMO BLEACH COLOUR SAFE 250ML', 'MOLO WHOLE MILK 200ML', 'SUNLIGHT D/WASHING PASTE 250G', 'NIVEA COOLKICK 100ML', 'KNORR BEEF CHILLI CUBES SOFT 6', 'GO BUTTER COOKIES 100G', 'BIRYANI 25KG BAG', 'MANJI GLUCOSE BISCUITS 100G', 'BELLA TOILET ROLLS 4PK', 'BABY WIPES', 'RANJUH MANDAZI 180G', 'WOW SUGARED 20G', 'WHITE WASH 1KG CREAM', 'PEP COCOPINE JUICE 1LTR', 'SB SHINNY SPONGES 1PACK', 'SB PAN SCRUBBER WITH SPONGE 1P', "DADDY'S CHOICE  2KG", 'KENSALT 1KG', 'HANAN JUMBO TISSUE', 'POSTMAN 10L', 'PACKING BAGS GUNIA #35', 'POSTMAN IL', 'ARIMIS 50G', 'TOILEX POA PRINTED RED', 'MELVINS TEA GINGER 100G', 'STONEY ZERO SUGAR 350ML', 'KASUKU 250GMS', 'RHINO KUBWA', 'NALA INSTANT NOODLES', 'BROOKSIDE MILK POWDER 15G', 'EDEN TEA 50G', 'FURAHA MAIZE 2KG', 'ROYAL NATURAL YOGHURT 500ML', 'REXONA MEN QUANTUM 25ML', 'CENTRAL SWEET BREAD 800G', 'SOFTCARE DIAPERS L/L 6', 'WAFERS', 'ARIEL DOWNY 500G', 'MANJI MARIE BISCUITS 80G', 'KASUKU 1KG', 'RANJU CHOCOLATE MUFFIN 300G', 'YAMI WHITE BREAD 400G', 'CHICO BUDS B/SIZE', 'GOAL SWEETS', 'CENTRAL BAKERS BREAD 400G', 'SHIBE MAIZE MEAL 2KG', 'MANJI FAMILY CLASSIC 75G', 'GRACIES VANILLA YOGHURT 250ML ', 'BELLA JUNIOUR TISSUE', 'CENTRAL BREAD 800G', 'YEGO CHAI ORANGE 100GMS', 'A-STAR RULED 96PGS', 'TUPIKE 2KG', 'DAWN PEKEE SMART 4PK', 'CLASSIC NATURAL SOAP 1 KG', 'AJAB WHEAT FLOUR 1kg', 'gumboots sadak', 'SCISSORS M/S  Y-60', 'OMO HANDWASH 75G', 'NESCAFE 3in1 CREAMY WHITE 18 G', 'TING TING 2IN 1', 'BOLT 145ML', 'SENIOUR ADULT DIAPER LARGE', 'SUNLIGHT TABLET 50G', 'GRACIES CHOCOLATE 250ML', 'GRACIES PASSION 250ML', 'MR.TOOTHPICK', 'SENSO ...

# %% [markdown]
# ## Grouping
# First we will group the data by the item description so as to get and plot the first and last 30 most sold and least sold items.

# %% [markdown]
# We will then sort the grouped data first by the total sales and then by the quantity sold.

# %% [markdown]
# ## Soring by total sales of items

# %%
# Grouping by item description
description_grouping = May_sales.groupby('Description')[['Qty_Sold', 'Sold_Price', 'Total_Sales']].sum()

# Sorting the grouped data by total sales in descending order
sorted_description_grouping_desc = description_grouping['Total_Sales'].sort_values(ascending=False)

# Extracting the top 30 items with the highest total sales
top_30 = sorted_description_grouping_desc.head(30)

# Sorting the grouped data by total sales in ascending order
sorted_description_grouping_asc = description_grouping['Total_Sales'].sort_values(ascending=True)

# Extracting the bottom 30 items with the lowest total sales
bottom_30 = sorted_description_grouping_asc.head(30)

# Create subplots
fig, axs = plt.subplots(1, 2, figsize=(10, 10))

# Plot for top 30 items with highest total sales
axs[0].bar(top_30.index, top_30, color='navy')
axs[0].set_ylabel('Total Sales')
axs[0].set_xlabel('Items')
axs[0].set_title('Top 30 Items with Highest Total Sales in May')
axs[0].tick_params(axis='x', rotation=90)

# Plot for bottom 30 items with lowest total sales
axs[1].bar(bottom_30.index, bottom_30, color='blue')
axs[1].set_ylabel('Total Sales')
axs[1].set_xlabel('Items')
axs[1].set_title('Bottom 30 Items with Lowest Total Sales in May')
axs[1].tick_params(axis='x', rotation=90)

# Adjust layout to prevent overlap
plt.tight_layout()

# Show plots
plt.show()

# %% [markdown]
# Most of the least bought items are under the foodstuff category.There are a few stationeris and medicine.There is just one item under the toiletries category. This might be due to the fact students were going back to school and did their toiletries shopping there.
# Since the supermarket is in a town with several bookshops and chemists thing can explain the low sales from the stationeries and medicine.

# %% [markdown]
# # Soring by quantity sold

# %% [markdown]
# ## Top 30 most sold items

# %%
# Grouping by item description
description_grouping = May_sales.groupby('Description')[['Qty_Sold', 'Sold_Price', 'Total_Sales']].sum()

# Sorting the grouped data by the total sales in descending order
sorted_description_grouping = description_grouping['Qty_Sold'].sort_values(ascending= False)

# Extracting the top 30 items with the highest total sales
top_30 = sorted_description_grouping.head(30)

# Getting the indexes of the top 30 items (item descriptions)
item_description = top_30.index

# Plotting the data
plt.bar(item_description, top_30, color='red')

# Set x and y-axis titles
plt.ylabel('Quantity sold')
plt.xlabel('Items')

# Set graph title
plt.title('Quantity sold of top 30 bought Goods in May')

# Rotate x-axis labels for better readability
plt.xticks(rotation=90, ha='right')

# Show graph
plt.show()

# %% [markdown]
# Most of the items are food stuffs , most of them as expected are in the top 30 items with highest total sales.
# From the bar plot we can see that one of the most bought item are the packing bags showing that most people don't carry / don't reuse shopping bags as they go to the supermarket.
#
# The balance,deposit and addation 'items' are irrelevant hence we delete them.

# %%
May_sales.shape
# Out:
# (106435, 7)

# %%
May_sales = May_sales[May_sales['Description'] != 'DEPOSIT']

May_sales = May_sales[May_sales['Description'] != 'BALANCE']

May_sales = May_sales[May_sales['Description'] != 'addation']

# %%
May_sales.shape
# Out:
# (106306, 7)

# %%
# Grouping by item description
description_grouping = May_sales.groupby('Description')[['Qty_Sold', 'Sold_Price', 'Total_Sales']].sum()

# Sorting the grouped data by the quantity sold in descending order
sorted_description_grouping_desc = description_grouping['Qty_Sold'].sort_values(ascending=False)

# Extracting the top 30 items with the highest quantity sold
top_30 = sorted_description_grouping_desc.head(30)

# Sorting the grouped data by the quantity sold in ascending order
sorted_description_grouping_asc = description_grouping['Qty_Sold'].sort_values(ascending=True)

# Extracting the bottom 30 items with the lowest quantity sold
bottom_30 = sorted_description_grouping_asc.head(30)

# Create subplots
fig, axs = plt.subplots(1, 2, figsize=(10, 10))

# Plot for top 30 items with highest quantity sold
axs[0].bar(top_30.index, top_30, color='orangered')
axs[0].set_ylabel('Quantity Sold')
axs[0].set_xlabel('Items')
axs[0].set_title('Top 30 Items with Highest Quantity Sold in May')
axs[0].tick_params(axis='x', rotation=90)

# Plot for bottom 30 items with lowest quantity sold
axs[1].bar(bottom_30.index, bottom_30, color='brown')
axs[1].set_ylabel('Quantity Sold')
axs[1].set_xlabel('Items')
axs[1].set_title('Bottom 30 Items with Lowest Quantity Sold in May')
axs[1].tick_params(axis='x', rotation=90)

# Adjust layout to prevent overlap
plt.tight_layout()

# Show plots
plt.show()

# %% [markdown]
# The bar graph above shows that goods bought in bales are the least bought(quantity wise) this is because they are not counted as pieces .....eg 1 bale of maize flour has 24 2kg pieces.
# Looks like most toiletries are the hav ethe least bought items in quantity.

# %% [markdown]
# ## Analysis by sales tax

# %% [markdown]
# Now let's look at the impact of tax on prices of goods and sales
# We'll look at the sales tax

# %%
May_sales.head()
# Out:
#        Item                    Description  Qty_Sold  Sold_Price  Total_Sales  \
# 0       D30                 DOUBLE BISCUIT       3.0          30           90
# 1  6.16E+12  DAWN PEKEE TISSUE SINGLE PACK       1.0          30           30
# 2  6.17E+12   GRACIES STRAWBERRY CUP 250ML       1.0          60           60
# 3       D30                 DOUBLE BISCUIT       2.0          30           60
# 4  6.17E+12  ELLY'S &JAYS PURE SEASALT 1KG       1.0         290          290
#
#    Total (Tax_Ex)  Sales_Tax
# 0         77.5862    12.4138
# 1         30.0000     0.0000
# 2         51.7241     8.2759
# 3         51.7241     8.2759
# 4        290.0000     0.0000

# %% [markdown]
# Since there are many duplicates in the dataset, and each item can have different quantity sold hence different sales tax value. Let us look at one item.

# %%
May_sales[May_sales['Description'] == 'DOUBLE BISCUIT']
# Out:
#        Item     Description  Qty_Sold  Sold_Price  Total_Sales  \
# 0       D30  DOUBLE BISCUIT       3.0          30           90
# 3       D30  DOUBLE BISCUIT       2.0          30           60
# 83      D30  DOUBLE BISCUIT       1.0          30           30
# 240     D30  DOUBLE BISCUIT       1.0          30           30
# 672     D30  DOUBLE BISCUIT       2.0          30           60
# ...     ...             ...       ...         ...          ...
# 106409  D30  DOUBLE BISCUIT       5.0          30          150
# 106437  D30  DOUBLE BISCUIT       1.0          30           30
# 106573  D30  DOUBLE BISCUIT       2.0          30           60
# 106739  D30  DOUBLE BISCUIT       1.0          30           30
# 106741  D30  DOUBLE BISCUIT       1.0          30           30
#
#         Total (Tax_Ex)  Sales_Tax
# 0              77.5862    12.4138
# 3              51.7241     8.2759
# 83             25.8621     4.1379
# 240            25.8621     4.1379
# 672            51.7241     8.2759
# ...                ...        ...
# 106409        129.3104    20.6896
# 106437         25.8621     4.1379
# 106573         51.7241     8.2759
# 106739         25.8621     4.1379
# 106741         25.8621     4.1379
#
# [1070 rows x 7 columns]

# %% [markdown]
# The value of the sales tax is dependant on the quantity sold. This is difficult to work with. We will therefore create a new column that calculates individual sales tax, basically sales tax (total) divided by the quantity sold.

# %%
May_sales['Individual_sales_tax'] = May_sales['Sales_Tax'] / May_sales['Qty_Sold']

# %% [markdown]
# Let's look at the double biscuit again.

# %%
May_sales[May_sales['Description'] == 'DOUBLE BISCUIT']
# Out:
#        Item     Description  Qty_Sold  Sold_Price  Total_Sales  \
# 0       D30  DOUBLE BISCUIT       3.0          30           90
# 3       D30  DOUBLE BISCUIT       2.0          30           60
# 83      D30  DOUBLE BISCUIT       1.0          30           30
# 240     D30  DOUBLE BISCUIT       1.0          30           30
# 672     D30  DOUBLE BISCUIT       2.0          30           60
# ...     ...             ...       ...         ...          ...
# 106409  D30  DOUBLE BISCUIT       5.0          30          150
# 106437  D30  DOUBLE BISCUIT       1.0          30           30
# 106573  D30  DOUBLE BISCUIT       2.0          30           60
# 106739  D30  DOUBLE BISCUIT       1.0          30           30
# 106741  D30  DOUBLE BISCUIT       1.0          30           30
#
#         Total (Tax_Ex)  Sales_Tax  Individual_sales_tax
# 0              77.5862    12.4138              4.137933
# 3              51.7241     8.2759              4.137950
# 83             25.8621     4.1379              4.137900
# 240            25.8621     4.1379              4.137900
# 672            51.7241     8.2759              4.137950
# ...                ...        ...                   ...
# 106409        129.3104    20.6896              4.137920
# 106437         25.8621     4.1379              4.137900
# 106573         51.7241     8.2759              4.137950
# 106739         25.8621     4.1379              4.137900
# 106741         25.8621     4.1379              4.137900
#
# [1070 rows x 8 columns]

# %% [markdown]
# This is easier to work with now.

# %%
May_sales.head()
# Out:
#        Item                    Description  Qty_Sold  Sold_Price  Total_Sales  \
# 0       D30                 DOUBLE BISCUIT       3.0          30           90
# 1  6.16E+12  DAWN PEKEE TISSUE SINGLE PACK       1.0          30           30
# 2  6.17E+12   GRACIES STRAWBERRY CUP 250ML       1.0          60           60
# 3       D30                 DOUBLE BISCUIT       2.0          30           60
# 4  6.17E+12  ELLY'S &JAYS PURE SEASALT 1KG       1.0         290          290
#
#    Total (Tax_Ex)  Sales_Tax  Individual_sales_tax
# 0         77.5862    12.4138              4.137933
# 1         30.0000     0.0000              0.000000
# 2         51.7241     8.2759              8.275900
# 3         51.7241     8.2759              4.137950
# 4        290.0000     0.0000              0.000000

# %% [markdown]
# Some of the goods seem to be tax free, let's have a  look at them.

# %%
No_tax = May_sales[May_sales['Individual_sales_tax']== 0]

# %%
No_tax.head(40)
# Out:
#          Item                     Description  Qty_Sold  Sold_Price  \
# 1    6.16E+12   DAWN PEKEE TISSUE SINGLE PACK       1.0          30
# 4    6.17E+12   ELLY'S &JAYS PURE SEASALT 1KG       1.0         290
# 8         301             CENTRAL BIRYANI 1Kg       1.0         120
# 10   6.16E+12                 NESTLE MILO 90G       1.0         160
# 13   6.17E+12      BROADWAYS WHITE BREAD 400G       1.0          65
# 18   6.16E+12          GEISHA BLACK SOAP 200G       1.0         140
# 29   6.16E+12            AJAB WHEAT FLOUR 2kg       1.0         190
# 33   6.16E+12            TAMAM MAIZE MEAL 2KG       1.0         115
# 34   6.16E+12                 MWANZO MPYA 1KG       1.0          55
# 41        C95             CENTRAL  BREAD 600G       4.0          95
# 44   6.16E+12            AJAB WHEAT FLOUR 2kg       2.0         190
# 46        301             CENTRAL BIRYANI 1Kg       2.0         120
# 50   6.17E+12      BROADWAYS WHITE BREAD 400G       1.0          65
# 57       9623   CENTRAL  W/ MEAL BREAD  500GM       2.0          60
# 63   6.16E+12  MOUNTAIN FRESH LONG LIFE 500ML       1.0          65
# 69        C65       CENTRAL SWEET BREAD 400GM       1.0          65
# 72   6.16E+12            SOKO ALL PURPOSE 1KG       1.0          90
# 77        301             CENTRAL BIRYANI 1Kg       2.0         120
# 90   7.50E+12                           nan 3       1.0        1820
# 95        301             CENTRAL BIRYANI 1Kg       1.0         120
# 105       C95             CENTRAL  BREAD 600G       2.0          95
# 107  6.17E+12                MAISHA FLOUR 1KG       1.0          90
# 114  8.93E+12                   PEPSODENT 30G       1.0          50
# 118  6.91E+11               DADDYS CHOICE 1KG       1.0          60
# 120  6.16E+12                   enlite 3watts       1.0         200
# 128  6.16E+12           MOLO WHOLE MILK 200ML       4.0          30
# 134     10060                BIRYANI 25KG BAG       1.0        2680
# 145  6.92E+11             DADDY'S CHOICE  2KG       2.0         120
# 149  6.16E+12            AJAB WHEAT FLOUR 2kg       5.0         190
# 153  6.16E+12            AJAB WHEAT FLOUR 2kg       1.0         190
# 154  6.92E+11             DADDY'S CHOICE  2KG       2.0         120
# 155       301             CENTRAL BIRYANI 1Kg       3.0         120
# 164       301             CENTRAL BIRYANI 1Kg       2.0         120
# 169  7.26E+11                FURAHA MAIZE 2KG       1.0         125
# 174  6.17E+12          SOFTCARE DIAPERS L/L 6       1.0         150
# 186       C60       CENTRAL BAKERS BREAD 400G       2.0          60
# 187  6.16E+12            SHIBE MAIZE MEAL 2KG       1.0         120
# 190       301             CENTRAL BIRYANI 1Kg       2.0         120
# 196  6.16E+12         YEGO CHAI ORANGE 100GMS       1.0          30
# 200  6.17E+12                      TUPIKE 2KG       1.0         125
#
#      Total_Sales  Total (Tax_Ex)  Sales_Tax  Individual_sales_tax
# 1             30            30.0        0.0                   0.0
# 4            290           290.0        0.0                   0.0
# 8            120           120.0        0.0                   0.0
# 10           160           160.0        0.0                   0.0
# 13            65            65.0        0.0                   0.0
# 18           140           140.0        0.0                   0.0
# 29           190           190.0        0.0                   0.0
# 33           115           115.0        0.0                   0.0
# 34            55            55.0        0.0                   0.0
# 41           380           380.0        0.0                   0.0
# 44           380           380.0        0.0                   0.0
# 46           240           240.0        0.0                   0.0
# 50            65            65.0        0.0                   0.0
# 57           120           120.0        0.0                   0.0
# 63            65            65.0        0.0                   0.0
# 69            65            65.0        0.0                   0.0
# 72            90            90.0        0.0                   0.0
# 77           240           240.0        0.0                   0.0
# 90          1820          1820.0        0.0                   0.0
# 95           120           120.0        0.0                   0.0
# 105          190           190.0        0.0                   0.0
# 107           90            90.0        0.0                   0.0
# 114           50            50.0        0.0                   0.0
# 118           60            60.0        0.0                   0.0
# 120          200           200.0        0.0                   0.0
# 128          120           120.0        0.0                   0.0
# 134         2680          2680.0        0.0                   0.0
# 145          240           240.0        0.0                   0.0
# 149          950           950.0        0.0                   0.0
# 153          190           190.0        0.0                   0.0
# 154          240           240.0        0.0                   0.0
# 155          360           360.0        0.0                   0.0
# 164          240           240.0        0.0                   0.0
# 169          125           125.0        0.0                   0.0
# 174          150           150.0        0.0                   0.0
# 186          120           120.0        0.0                   0.0
# 187          120           120.0        0.0                   0.0
# 190          240           240.0        0.0                   0.0
# 196           30            30.0        0.0                   0.0
# 200          125           125.0        0.0                   0.0

# %%
No_tax.tail()
# Out:
#             Item           Description  Qty_Sold  Sold_Price  Total_Sales  \
# 107089      CCBN           COCONUT BUN       1.0          55           55
# 107090  7.92E+11      RAHA PREMIUM 2KG       1.0         185          185
# 107098  6.16E+12  MOUNTAIN FRESH 500ML       5.0          60          300
# 107099       301   CENTRAL BIRYANI 1Kg       2.0         120          240
# 107101       301   CENTRAL BIRYANI 1Kg       1.0         120          120
#
#         Total (Tax_Ex)  Sales_Tax  Individual_sales_tax
# 107089            55.0        0.0                   0.0
# 107090           185.0        0.0                   0.0
# 107098           300.0        0.0                   0.0
# 107099           240.0        0.0                   0.0
# 107101           120.0        0.0                   0.0

# %% [markdown]
# Most of them are food stuffs . We can remove them since they do not aid with the tax analysis

# %%
May_sales.shape
# Out:
# (106306, 8)

# %%
May_sales = May_sales[May_sales['Individual_sales_tax'] != 0]

# %%
May_sales.shape
# Out:
# (79479, 8)

# %%
May_sales.head()
# Out:
#        Item                   Description  Qty_Sold  Sold_Price  Total_Sales  \
# 0       D30                DOUBLE BISCUIT       3.0          30           90
# 2  6.17E+12  GRACIES STRAWBERRY CUP 250ML       1.0          60           60
# 3       D30                DOUBLE BISCUIT       2.0          30           60
# 5      1422                   candle 1 pc       1.0          10           10
# 6  6.00E+12      DAIRY MILK TOP DECK 80GM       1.0         230          230
#
#    Total (Tax_Ex)  Sales_Tax  Individual_sales_tax
# 0         77.5862    12.4138              4.137933
# 2         51.7241     8.2759              8.275900
# 3         51.7241     8.2759              4.137950
# 5          8.6207     1.3793              1.379300
# 6        198.2759    31.7241             31.724100

# %%
len(May_sales['Description'].unique())
# Out:
# 3928

# %%
#get unique item description so at to work with unique items
unique_rows = May_sales.drop_duplicates(subset='Description')

# %%
unique_rows.shape
# Out:
# (3928, 8)

# %%
unique_rows.head()
# Out:
#        Item                   Description  Qty_Sold  Sold_Price  Total_Sales  \
# 0       D30                DOUBLE BISCUIT       3.0          30           90
# 2  6.17E+12  GRACIES STRAWBERRY CUP 250ML       1.0          60           60
# 5      1422                   candle 1 pc       1.0          10           10
# 6  6.00E+12      DAIRY MILK TOP DECK 80GM       1.0         230          230
# 7       GFT            TROPICAL SWEET 3'S       1.0          10           10
#
#    Total (Tax_Ex)  Sales_Tax  Individual_sales_tax
# 0         77.5862    12.4138              4.137933
# 2         51.7241     8.2759              8.275900
# 5          8.6207     1.3793              1.379300
# 6        198.2759    31.7241             31.724100
# 7          8.6207     1.3793              1.379300

# %%
unique_rows.describe()
# Out:
#           Qty_Sold    Sold_Price   Total_Sales  Total (Tax_Ex)    Sales_Tax  \
# count  3928.000000   3928.000000   3928.000000     3928.000000  3928.000000
# mean      1.235743    353.242617    372.817464      321.394368    51.423097
# std       1.617301    943.304189    957.013729      825.011835   132.001894
# min       0.500000      1.000000      1.000000        0.862100     0.137900
# 25%       1.000000     80.000000     80.000000       68.965500    11.034500
# 50%       1.000000    150.000000    160.000000      137.931000    22.069000
# 75%       1.000000    300.000000    315.000000      271.551700    43.448300
# max      50.000000  23500.000000  23500.000000    20258.620700  3241.379300
#
#        Individual_sales_tax
# count           3928.000000
# mean              48.723118
# std              130.110923
# min                0.137900
# 25%               11.034496
# 50%               20.689600
# 75%               41.379300
# max             3241.379300

# %%
#sort the rows by the individual sales tax column 
sorted_rows = unique_rows.sort_values(by='Individual_sales_tax', ascending=True)  

# Display the sorted DataFrame
print(sorted_rows)
# Out:
#          Item             Description  Qty_Sold  Sold_Price  Total_Sales  \
# 185      GOAL             GOAL SWEETS       1.0           1            1
# 41475    POPS   WHITE POPS SWEETS PKT      30.0           1           30
# 13143  100015            envelope m/s       5.0           2           10
# 44462      77         GIRLS BEADS S/S      50.0           2          100
# 90859     UIH  TROPICAL SWEET 1 PIECE       1.0           5            5
# ...       ...                     ...       ...         ...          ...
# 68470   74003     MIKA DISPENSER 2302       1.0       13500        13500
# 40307   30503  VITRON 32'' TV DIGITAL       1.0       14000        14000
# 33879   33020    VITRON 32'' SMART TV       1.0       15000        15000
# 499     AL120         AILYONS 32'' TV       1.0       15000        15000
# 74676     VIT   VITRON 40 '' SMART TV       1.0       23500        23500
#
#        Total (Tax_Ex)  Sales_Tax  Individual_sales_tax
# 185            0.8621     0.1379              0.137900
# 41475         25.8621     4.1379              0.137930
# 13143          8.6207     1.3793              0.275860
# 44462         86.2069    13.7931              0.275862
# 90859          4.3104     0.6896              0.689600
# ...               ...        ...                   ...
# 68470      11637.9310  1862.0690           1862.069000
# 40307      12068.9655  1931.0345           1931.034500
# 33879      12931.0345  2068.9655           2068.965500
# 499        12931.0345  2068.9655           2068.965500
# 74676      20258.6207  3241.3793           3241.379300
#
# [3928 rows x 8 columns]

# %% [markdown]
# # Top 30 items with highest tax and bottom 30 items with lowest tax

# %%
# Data for items with highest tax
items_with_highest_tax = sorted_rows.tail(30)
sorted_items_with_highest_tax = items_with_highest_tax.sort_values(by='Individual_sales_tax', ascending=False)

item_description_highest = sorted_items_with_highest_tax['Description']
tax_highest = sorted_items_with_highest_tax['Individual_sales_tax']


# Data for items with lowest tax
items_with_lowest_tax = sorted_rows.head(30)
item_description_lowest = items_with_lowest_tax['Description']
tax_lowest = items_with_lowest_tax['Individual_sales_tax']


# Create subplots
fig, axs = plt.subplots(1, 2, figsize=(10, 10))

# Plot for items with highest tax
axs[0].bar(item_description_highest, tax_highest, color='limegreen')
axs[0].set_ylabel('Tax')
axs[0].set_xlabel('Items')
axs[0].set_title('Items with Highest Tax')
axs[0].tick_params(axis='x', rotation=90)

# Plot for items with lowest tax
axs[1].bar(item_description_lowest, tax_lowest, color='forestgreen')
axs[1].set_ylabel('Tax')
axs[1].set_xlabel('Items')
axs[1].set_title('Items with Lowest Tax')
axs[1].tick_params(axis='x', rotation=90)


# Adjust layout to prevent overlap
plt.tight_layout()

# Show plots
plt.show()
